# %%
import numpy as np
import pandas as pd
import vectorbt as vbt
import quantstats as qs
import matplotlib.pyplot as plt

from binance import Client
from binance.enums import HistoricalKlinesType

# %% [markdown]
# ### 抓資料並切割樣本

# %%
#get binance data

client = Client()
value = client.get_historical_klines(symbol = 'BTCUSDT', 
                                      interval = '15m', 
                                      start_str = '2020-01-01', 
                                      end_str = '2023-06-30',
                                      klines_type=HistoricalKlinesType.FUTURES)

columns_name = ['openTime', 'Open', 'High', 'Low', 'Close', 'Volume', 'closeTime', 
                'quoteVolume', 'numTrade', 'takerBuyVolume', 'takerBuyQuoteVolume', 'ignore']

df = pd.DataFrame(value)
df.columns = columns_name
df['openTime']= pd.to_datetime(df['openTime'], unit='ms')
df = df.drop(['ignore', 'closeTime'], axis=1)
df = df.sort_values('openTime', ascending=True)
df = df.set_index('openTime')
df = df.astype(float)
df = df[~df.index.duplicated(keep='first')]

# %%
#split to in and out sample
price_all = df[['Open', 'High', 'Low', 'Close']]
price_is = price_all['2020-01-01':'2022-08-31'] # in sample data
price_os = price_all['2022-09-01':'2023-06-30'] # out sample data
print(price_all)
print(price_is)
print(price_os)
# Out:
#                          Open      High       Low     Close
# openTime
# 2020-01-01 00:00:00   7189.43   7190.52   7172.94   7176.26
# 2020-01-01 00:15:00   7176.22   7179.41   7170.69   7172.36
# 2020-01-01 00:30:00   7172.79   7179.45   7170.61   7174.83
# 2020-01-01 00:45:00   7174.51   7179.36   7170.15   7171.55
# 2020-01-01 01:00:00   7171.43   7188.77   7171.10   7186.60
# ...                       ...       ...       ...       ...
# 2023-06-29 23:00:00  30402.50  30409.00  30380.00  30395.70
# 2023-06-29 23:15:00  30395.70  30476.00  30383.10  30472.00
# 2023-06-29 23:30:00  30472.10  30523.50  30460.00  30470.00
# 2023-06-29 23:45:00  30469.90  30470.00  30430.40  30439.90
# 2023-06-30 00:00:00  30439.90  30466.80  30408.00  30408.00
#
# [122497 rows x 4 columns]
#                          Open      High       Low     Close
# openTime
# 2020-01-01 00:00:00   7189.43   7190.52   7172.94   7176.26
# 2020-01-01 00:15:00   7176.22   7179.41   7170.69   7172.36
# 2020-01-01 00:30:00   7172.79   7179.45   7170.61   7174.83
# 2020-01-01 00:45:00   7174.51   7179.36   7170.15   7171.55
# 2020-01-01 01:00:00   7171.43   7188.77   7171.10   7186.60
# ...                       ...       ...       ...       ...
# 2022-08-31 22:45:00  20108.20  20160.40  20100.40  20148.20
# 2022-08-31 23:00:00  20148.30  20148.30  20033.60  20043.00
# 2022-08-31 23:15:00  20043.10  20061.50  20001.00  20004.80
# 2022-08-31 23:30:00  20004.80  20009.10  19959.80  19998.90
# 2022-08-31 23:45:00  19999.00  20047.40  19996.90  20041.50
#
# [93504 rows x 4 columns]
#                         Open     High      Low    Close
# openTime
# 2022-09-01 00:00:00  20041.4  20126.2  19999.0  20099.4
# 2022-09-01 00:15:00  20099.5  20122.5  20051.5  20089.7
# 2022-09-01 00:30:00  20089.7  20112.7  19910.0  19914.9
# 2022-09-01 00:45:00  19914.9  20080.0  19910.0  20057.2
# 2022-09-01 01:00:00  20057.2  20122.9  20044.7  20059.6
# ...                      ...      ...      ...      ...
# 2023-06-29 23:00:00  30402.5  30409.0  30380.0  30395.7
# 2023-06-29 23:15:00  30395.7  30476.0  30383.1  30472.0
# 2023-06-29 23:30:00  30472.1  30523.5  30460.0  30470.0
# 2023-06-29 23:45:00  30469.9  30470.0  30430.4  30439.9
# 2023-06-30 00:00:00  30439.9  30466.8  30408.0  30408.0
#
# [28993 rows x 4 columns]

# %% [markdown]
# ### 定義策略

# %%
#double rsi as signal and filter
def rsi_long(close, rsi_window = 29, filter_window = 50):

    rsi_crossover = vbt.RSI.run(close, window=rsi_window).rsi_crossed_above(70).to_numpy()
    rsi_crossunder = vbt.RSI.run(close, window=rsi_window).rsi_crossed_below(30).to_numpy()

    rsi_filter = vbt.RSI.run(close, window = filter_window).rsi.to_numpy()

    signal = np.where(rsi_crossover & (rsi_filter > 70), 1, 0)
    signal = np.where(rsi_crossunder, -1, signal)

    return signal

MyInd = vbt.IndicatorFactory(
    class_name = 'rsi_long',
    short_name = 'long',
    input_names = ['close'],
    param_names = ['rsi_window', 'filter_window'],
    output_names = ['signals'] 
).from_apply_func(rsi_long, keep_pd=True)

# %% [markdown]
# ### 參數優化

# %%
#run strategy and do parameter optimization on in sample data

win = np.arange(20, 50)
signal = MyInd.run(price_is['Close'] , rsi_window=win, filter_window=win, param_product = True)

entries = signal.signals == 1
exits = signal.signals == -1

portfolio = vbt.Portfolio.from_signals(
    price_is['Close'], 
    entries, 
    exits,
    freq = '15m', 
    direction = 'longonly', 
    sl_stop = 0.03,
    fees = 0.0015
)

print(portfolio.total_return().sort_values())
print(portfolio.sharpe_ratio().sort_values())
# Out:
# long_rsi_window  long_filter_window
# 20               20                   -0.592385
# 21               21                   -0.528170
# 22               41                   -0.449519
#                  42                   -0.423551
#                  43                   -0.394123
#                                          ...
# 49               21                    4.982664
# 32               34                    5.034642
# 49               33                    5.117464
#                  20                    5.157155
#                  38                    5.674729
# Name: total_return, Length: 900, dtype: float64
# long_rsi_window  long_filter_window
# 22               41                   -0.805691
#                  42                   -0.721886
#                  43                   -0.712548
# 21               48                   -0.612060
#                  44                   -0.562227
#                                          ...
# 32               34                    1.777865
# 33               45                    1.821711
# 49               38                    1.823256
# 32               38                    1.857084
#                  39                    1.877984
# Name: sharpe_ratio, Length: 900, dtype: float64

# %%
pf = pd.concat([portfolio.total_return(),  portfolio.sharpe_ratio()], axis=1)

# %%
# 畫出參數高原
import plotly.graph_objects as go

x = pf.loc[pf['total_return'] > 0].index.get_level_values(0)
y = pf.loc[pf['total_return'] > 0].index.get_level_values(1)
z = pf.loc[pf['total_return'] > 0]['total_return']
data = (pf.loc[pf['total_return'] > 0]['sharpe_ratio'])
scatter_data = go.Scatter3d(
    x=x,
    y=y,
    z=z,
    mode='markers',
    marker=dict(
        color=data,  # 将第四维数据用颜色表示
        colorscale='Viridis',
        colorbar=dict(title='Sharpe')  # 添加颜色条
    )
)

# 创建图布局
layout = go.Layout(
    title='3D Scatter Plot',
    scene=dict(
        xaxis=dict(title='rsi_window'),
        yaxis=dict(title='filter_window'),
        zaxis=dict(title='return')
    )
)

# 创建图像的 Figure 对象并绘制图像
fig = go.Figure(data=[scatter_data], layout=layout)
fig.show()
fig.write_html(file = '3d_plot.html' , auto_open  = True)#圖片儲存並自動展

# %%
#select strategies with best sharpe ratio
idx_best_10_sharpe = pf.loc[pf.index.get_level_values(0) > 25].sort_values(by = 'sharpe_ratio', ascending=False).index[0:10].to_list()
idx_best_10_return = pf.loc[pf.index.get_level_values(0) > 25].sort_values(by = 'total_return', ascending=False).index[0:10].to_list()
idx_best_5_sharpe = pf.loc[np.logical_and(pf.index.get_level_values(0) > 25, pf.index.get_level_values(0) < pf.index.get_level_values(1))].sort_values(by = 'sharpe_ratio', ascending=False).index[0:5].to_list()
idx_best_5_return = pf.loc[pf.index.get_level_values(0) > 25].sort_values(by = 'total_return', ascending=False).index[0:5].to_list()
print("best 10 sharpe: " + str(idx_best_10_sharpe))
print("best 10 return: " + str(idx_best_10_return))
print("best 5 sharpe: " + str(idx_best_5_sharpe))
print("best 5 return: " + str(idx_best_5_return))
# Out:
# best 10 sharpe: [(32, 39), (32, 38), (49, 38), (33, 45), (32, 34), (44, 49), (33, 37), (49, 33), (49, 20), (32, 44)]
# best 10 return: [(49, 38), (49, 20), (49, 33), (32, 34), (49, 21), (49, 31), (32, 38), (49, 32), (32, 39), (49, 36)]
# best 5 sharpe: [(32, 39), (32, 38), (33, 45), (32, 34), (44, 49)]
# best 5 return: [(49, 38), (49, 20), (49, 33), (32, 34), (49, 21)]

# %%
entries_list = []
exits_list = []

for param in idx_best_5_sharpe:

    signal = MyInd.run(price_all['Close'] , rsi_window=param[0], filter_window=param[1], param_product = True)

    entries = signal.signals == 1
    exits = signal.signals == -1
    entries_list.append(entries)
    exits_list.append(exits)

entries_df = pd.concat(entries_list, axis = 1)
exits_df = pd.concat(exits_list, axis = 1)

portfolio = vbt.Portfolio.from_signals(
    price_all['Close'], 
    entries_df, 
    exits_df,
    freq = '15m', 
    direction = 'longonly',
    sl_stop = 0.025,
    fees = 0.0015
)

print(portfolio.returns())
# Out:
#                            32                  33        32        44
#                            39        38        45        34        49
#                         Close     Close     Close     Close     Close
# openTime
# 2020-01-01 00:00:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-01-01 00:15:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-01-01 00:30:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-01-01 00:45:00  0.000000  0.000000  0.000000  0.000000  0.000000
# 2020-01-01 01:00:00  0.000000  0.000000  0.000000  0.000000  0.000000
# ...                       ...       ...       ...       ...       ...
# 2023-06-29 23:00:00 -0.000224 -0.000224 -0.000224 -0.000224 -0.000224
# 2023-06-29 23:15:00  0.002510  0.002510  0.002510  0.002510  0.002510
# 2023-06-29 23:30:00 -0.000066 -0.000066 -0.000066 -0.000066 -0.000066
# 2023-06-29 23:45:00 -0.000988 -0.000988 -0.000988 -0.000988 -0.000988
# 2023-06-30 00:00:00 -0.001048 -0.001048 -0.001048 -0.001048 -0.001048
#
# [122497 rows x 5 columns]

# %%
rett = portfolio.returns()

n = 72 * 6
rolling_risk = rett.rolling(n).std()
w_df_ = ((1/rolling_risk).T/(1/rolling_risk).sum(axis = 1)).T

rett['rp'] = (rett * w_df_).sum(axis=1)

rett['eq'] = rett.iloc[:, :10].mean(axis = 1) 

rett.cumsum().plot()

df_metrics = pd.DataFrame()
for col in rett.columns:
    df_metrics[col] = qs.reports.metrics(rett[col], mode='full', display=False, periods_per_year =4 * 24 * 365)

df_metrics.head(50)
# Out:
#                           (32, 39, Close) (32, 38, Close) (33, 45, Close)  \
# Start Period                   2020-01-01      2020-01-01      2020-01-01
# End Period                     2023-06-30      2023-06-30      2023-06-30
# Risk-Free Rate                          0               0               0
# Time in Market                       0.32            0.33            0.26
# Cumulative Return                    8.44            8.19            7.44
# CAGR﹪                                0.56            0.55            0.52
# Sharpe                               1.93            1.86            2.04
# Prob. Sharpe Ratio                    1.0             1.0             1.0
# Smart Sharpe                         1.92            1.86            2.04
# Sortino                              2.75            2.66            2.94
# Smart Sortino                        2.74            2.65            2.94
# Sortino/√2                           1.94            1.88            2.08
# Smart Sortino/√2                     1.94            1.88            2.08
# Omega                                1.06            1.06            1.07
# Max Drawdown                        -0.21           -0.21            -0.2
# Longest DD Days                       211             278             292
# Volatility (ann.)                    0.37            0.38            0.32
# Calmar                               2.72             2.6            2.65
# Skew                                 -0.4           -0.28            0.08
# Kurtosis                            98.35           95.19           99.42
# Expected Daily                          0               0               0
# Expected Monthly                     0.05            0.05            0.05
# Expected Yearly                      0.75            0.74             0.7
# Kelly Criterion                      0.03            0.03            0.03
# Risk of Ruin                            0               0               0
# Daily Value-at-Risk                     0               0               0
# Expected Shortfall (cVaR)               0               0               0
# Max Consecutive Wins                 12.0            12.0            12.0
# Max Consecutive Losses               10.0            10.0             9.0
# Gain/Pain Ratio                      0.58            0.53            0.72
# Gain/Pain (1M)                       6.12            4.25            4.86
# Payoff Ratio                         1.01            1.01            1.01
# Profit Factor                        1.06            1.06            1.07
# Common Sense Ratio                   1.12            1.12            1.15
# CPC Index                            0.55            0.55            0.56
# Tail Ratio                           1.05            1.06            1.08
# Outlier Win Ratio                   14.73           14.45           16.79
# Outlier Loss Ratio                   2.69            2.71            2.42
# MTD                                   0.1            0.08            0.04
# 3M                                   0.05           -0.01            0.08
# 6M                                   0.41            0.33            0.77
# YTD                                  0.41            0.33            0.77
# 1Y                                    0.6            0.56            0.78
# 3Y (ann.)                             0.5            0.45            0.48
# 5Y (ann.)                            0.56            0.55            0.52
# 10Y (ann.)                           0.56            0.55            0.52
# All-time (ann.)                      0.56            0.55            0.52
# Best Day                             0.07            0.07            0.05
# Worst Day                           -0.08           -0.08           -0.06
# Best Month                           0.27             0.3            0.33
#
#                           (32, 34, Close) (44, 49, Close)    (rp, , )  \
# Start Period                   2020-01-01      2020-01-01  2020-01-01
# End Period                     2023-06-30      2023-06-30  2023-06-30
# Risk-Free Rate                          0               0           0
# Time in Market                        0.4             0.3        0.27
# Cumulative Return                    6.37            7.09        4.89
# CAGR﹪                                0.48            0.51        0.42
# Sharpe                               1.62            1.86        1.91
# Prob. Sharpe Ratio                    1.0             1.0         1.0
# Smart Sharpe                         1.61            1.84        1.89
# Sortino                               2.3            2.61        2.73
# Smart Sortino                        2.29            2.58         2.7
# Sortino/√2                           1.63            1.85        1.93
# Smart Sortino/√2                     1.62            1.82        1.91
# Omega                                1.04            1.06        1.07
# Max Drawdown                         -0.3           -0.32       -0.17
# Longest DD Days                       206             350         292
# Volatility (ann.)                     0.4            0.35        0.29
# Calmar                                1.6            1.62        2.42
# Skew                                -0.28           -1.64       -0.26
# Kurtosis                            76.85          138.53      121.23
# Expected Daily                          0               0           0
# Expected Monthly                     0.05            0.05        0.04
# Expected Yearly                      0.65            0.69        0.56
# Kelly Criterion                      0.02            0.03        0.03
# Risk of Ruin                            0               0           0
# Daily Value-at-Risk                     0               0           0
# Expected Shortfall (cVaR)               0               0           0
# Max Consecutive Wins                 12.0            12.0        12.0
# Max Consecutive Losses               10.0            10.0        10.0
# Gain/Pain Ratio                      0.39             0.6        0.77
# Gain/Pain (1M)                        3.1            3.46        6.26
# Payoff Ratio                         1.01             1.0        1.01
# Profit Factor                        1.04            1.06        1.07
# Common Sense Ratio                   1.08            1.13        1.18
# CPC Index                            0.54            0.55        0.56
# Tail Ratio                           1.04            1.06         1.1
# Outlier Win Ratio                   12.36           15.15       17.82
# Outlier Loss Ratio                    3.0            2.62        2.68
# MTD                                  0.16            0.15        0.07
# 3M                                      0            0.07        0.03
# 6M                                    0.3            0.79        0.43
# YTD                                  0.31            0.79        0.43
# 1Y                                    0.2            0.49        0.41
# 3Y (ann.)                            0.36            0.38        0.39
# 5Y (ann.)                            0.48            0.51        0.42
# 10Y (ann.)                           0.48            0.51        0.42
# All-time (ann.)                      0.48            0.51        0.42
# Best Day                             0.07            0.05        0.05
# Worst Day                           -0.08           -0.09       -0.06
# Best Month                            0.3            0.49        0.22
#
#                              (eq, , )
# Start Period               2020-01-01
# End Period                 2023-06-30
# Risk-Free Rate                      0
# Time in Market                   0.49
# Cumulative Return                7.31
# CAGR﹪                            0.52
# Sharpe                           2.05
# Prob. Sharpe Ratio                1.0
# Smart Sharpe                     2.04
# Sortino                          2.93
# Smart Sortino                    2.91
# Sortino/√2                       2.07
# Smart Sortino/√2                 2.06
# Omega                            1.06
# Max Drawdown                    -0.18
# Longest DD Days                   168
# Volatility (ann.)                0.32
# Calmar                           2.81
# Skew                            -0.35
# Kurtosis                         92.6
# Expected Daily                      0
# Expected Monthly                 0.05
# Expected Yearly                   0.7
# Kelly Criterion                  0.03
# Risk of Ruin                        0
# Daily Value-at-Risk                 0
# Expected Shortfall (cVaR)           0
# Max Consecutive Wins             12.0
# Max Consecutive Losses           10.0
# Gain/Pain Ratio                  0.58
# Gain/Pain (1M)                   5.71
# Payoff Ratio                     1.03
# Profit Factor                    1.06
# Common Sense Ratio               1.13
# CPC Index                        0.55
# Tail Ratio                       1.06
# Outlier Win Ratio               11.89
# Outlier Loss Ratio               3.72
# MTD                               0.1
# 3M                               0.04
# 6M                                0.5
# YTD                               0.5
# 1Y                               0.51
# 3Y (ann.)                        0.44
# 5Y (ann.)                        0.52
# 10Y (ann.)                       0.52
# All-time (ann.)                  0.52
# Best Day                         0.05
# Worst Day                       -0.06
# Best Month                       0.25

# %%
from datetime import datetime

rett['btc'] = df['Close'].pct_change()
fig, ax = plt.subplots(figsize=(16,8))
rett[['eq', 'btc', 'rp']].cumsum().plot(ax=ax, title = 'Cumsum')
# Out:
# <Axes: title={'center': 'Cumsum'}, xlabel='openTime'>

# %%
qs_metrics = pd.DataFrame()

qs_metrics["benchmark"] = qs.reports.metrics(rett['btc'], mode='full', display=False, periods_per_year =4 * 24 * 365, compounded=False)
qs_metrics["eq_in_sample"] = qs.reports.metrics(rett['eq']['2020-01-01':'2022-08-31'], mode='full', display=False, periods_per_year =4 * 24 * 365, compounded = False)
qs_metrics["eq_out_sample"] = qs.reports.metrics(rett['eq']['2022-09-01':'2023-06-30'], mode='full', display=False, periods_per_year =4 * 24 * 365, compounded = False)
qs_metrics["eq_all"] = qs.reports.metrics(rett['eq'], mode='full', display=False, periods_per_year =4 * 24 * 365, compounded = False)
qs_metrics["rp_in_sample"] = qs.reports.metrics(rett['rp']['2020-01-01':'2022-08-31'], mode='full', display=False, periods_per_year =4 * 24 * 365, compounded = False)
qs_metrics["rp_out_sample"] = qs.reports.metrics(rett['rp']['2022-09-01':'2023-06-30'], mode='full', display=False, periods_per_year =4 * 24 * 365, compounded = False)
qs_metrics["rp_all"] = qs.reports.metrics(rett['rp'], mode='full', display=False, periods_per_year =4 * 24 * 365, compounded = False)

# %%
qs_metrics.head(60)
#qs_metrics.to_csv('metrics.csv')
# Out:
#                             benchmark eq_in_sample eq_out_sample      eq_all  \
# Start Period               2020-01-01   2020-01-01    2022-09-01  2020-01-01
# End Period                 2023-06-30   2022-08-31    2023-06-30  2023-06-30
# Risk-Free Rate                      0            0             0           0
# Time in Market                    1.0         0.48          0.51        0.49
# Total Return                     2.42         1.87          0.43         2.3
# CAGR﹪                            0.28         0.31          0.35        0.27
# Sharpe                           0.93          2.1          1.88        2.05
# Prob. Sharpe Ratio               0.96          1.0          0.96         1.0
# Smart Sharpe                     0.92         2.09          1.77        2.04
# Sortino                          1.32          3.0          2.71        2.93
# Smart Sortino                    1.31         2.98          2.55        2.91
# Sortino/√2                       0.93         2.12          1.91        2.07
# Smart Sortino/√2                 0.93          2.1           1.8        2.06
# Omega                            1.02         1.06          1.06        1.06
# Max Drawdown                    -0.77        -0.17         -0.18       -0.18
# Longest DD Days                   597          157           123         168
# Volatility (ann.)                0.75         0.33          0.27        0.32
# Calmar                           0.43          3.3          2.11        2.81
# Skew                             1.23         -0.4         -0.03       -0.35
# Kurtosis                       150.99        86.03         122.3        92.6
# Expected Daily                      0            0             0           0
# Expected Monthly                 0.04         0.05          0.04        0.05
# Expected Yearly                  0.11         0.57          0.19        0.53
# Kelly Criterion                  0.01         0.03          0.03        0.03
# Risk of Ruin                        0            0             0           0
# Daily Value-at-Risk             -0.01            0             0           0
# Expected Shortfall (cVaR)       -0.01            0             0           0
# Max Consecutive Wins             14.0         12.0          11.0        12.0
# Max Consecutive Losses           13.0         10.0           9.0        10.0
# Gain/Pain Ratio                  0.16          0.6           0.5        0.58
# Gain/Pain (1M)                   1.04         5.67          5.92        5.71
# Payoff Ratio                      1.0         1.02          1.03        1.03
# Profit Factor                    1.02         1.06          1.06        1.06
# Common Sense Ratio               1.03         1.12          1.12        1.13
# CPC Index                        0.51         0.55          0.55        0.55
# Tail Ratio                       1.01         1.06          1.06        1.06
# Outlier Win Ratio                4.73        11.73         12.15       11.89
# Outlier Loss Ratio               4.75         3.61          4.08        3.72
# MTD                              0.12        -0.01           0.1         0.1
# 3M                               0.09        -0.04          0.04        0.04
# 6M                               0.66         0.03          0.43        0.43
# YTD                              0.66         0.11          0.43        0.43
# 1Y                               0.55         0.27          0.43        0.45
# 3Y (ann.)                        0.27         0.31          0.35        0.26
# 5Y (ann.)                        0.28         0.31          0.35        0.27
# 10Y (ann.)                       0.28         0.31          0.35        0.27
# All-time (ann.)                  0.28         0.31          0.35        0.27
# Best Day                         0.24         0.05          0.04        0.05
# Worst Day                       -0.13        -0.06         -0.05       -0.06
# Best Month                       0.41         0.24          0.18        0.24
# Worst Month                     -0.37        -0.07         -0.05       -0.07
# Best Year                         1.7         1.15          0.43        1.15
# Worst Year                      -0.82         0.11             0        0.11
# Avg. Drawdown                   -0.03        -0.02         -0.02       -0.02
# Avg. Drawdown Days                  5            5             6           5
# Recovery Factor                  3.13        10.98          2.31       12.42
# Ulcer Index                      0.44         0.09           0.1        0.09
# Serenity Index                   0.03         0.28          0.04         0.3
# Avg. Up Month                     0.2         0.12          0.08        0.11
# Avg. Down Month                 -0.13        -0.03         -0.02       -0.02
#
#                           rp_in_sample rp_out_sample      rp_all
# Start Period                2020-01-01    2022-09-01  2020-01-01
# End Period                  2022-08-31    2023-06-30  2023-06-30
# Risk-Free Rate                       0             0           0
# Time in Market                    0.26          0.32        0.27
# Total Return                      1.54          0.38        1.92
# CAGR﹪                             0.27          0.31        0.24
# Sharpe                            1.95          1.75        1.91
# Prob. Sharpe Ratio                 1.0          0.94         1.0
# Smart Sharpe                      1.95          1.64        1.89
# Sortino                           2.78          2.53        2.73
# Smart Sortino                     2.78          2.38         2.7
# Sortino/√2                        1.97          1.79        1.93
# Smart Sortino/√2                  1.96          1.68        1.91
# Omega                             1.07          1.06        1.07
# Max Drawdown                     -0.17         -0.14       -0.17
# Longest DD Days                    167           123         292
# Volatility (ann.)                  0.3          0.26        0.29
# Calmar                            2.58          2.49        2.42
# Skew                              -0.4          0.41       -0.26
# Kurtosis                        116.68        137.72      121.23
# Expected Daily                       0             0           0
# Expected Monthly                  0.05          0.04        0.04
# Expected Yearly                   0.49          0.17        0.46
# Kelly Criterion                   0.04          0.03        0.03
# Risk of Ruin                         0             0           0
# Daily Value-at-Risk                  0             0           0
# Expected Shortfall (cVaR)            0             0           0
# Max Consecutive Wins              12.0          10.0        12.0
# Max Consecutive Losses            10.0           9.0        10.0
# Gain/Pain Ratio                   0.83          0.59        0.77
# Gain/Pain (1M)                    5.87          8.59        6.26
# Payoff Ratio                      1.01          1.01        1.01
# Profit Factor                     1.07          1.06        1.07
# Common Sense Ratio                1.18          1.15        1.18
# CPC Index                         0.56          0.55        0.56
# Tail Ratio                         1.1          1.08         1.1
# Outlier Win Ratio                18.16         15.93       17.82
# Outlier Loss Ratio                2.55           3.0        2.68
# MTD                              -0.02          0.07        0.07
# 3M                                0.01          0.03        0.03
# 6M                                0.07          0.38        0.38
# YTD                                0.2          0.38        0.38
# 1Y                                0.39          0.38        0.37
# 3Y (ann.)                         0.27          0.31        0.24
# 5Y (ann.)                         0.27          0.31        0.24
# 10Y (ann.)                        0.27          0.31        0.24
# All-time (ann.)                   0.27          0.31        0.24
# Best Day                          0.05          0.04        0.05
# Worst Day                        -0.06         -0.05       -0.06
# Best Month                        0.21          0.19        0.21
# Worst Month                       -0.1         -0.02        -0.1
# Best Year                         0.77          0.38        0.77
# Worst Year                         0.2         -0.01        0.19
# Avg. Drawdown                    -0.02         -0.02       -0.02
# Avg. Drawdown Days                   6             8           7
# Recovery Factor                    8.9          2.78       11.07
# Ulcer Index                       0.07          0.07        0.07
# Serenity Index                    0.27          0.06        0.33
# Avg. Up Month                     0.09          0.08        0.09
# Avg. Down Month                  -0.03         -0.01       -0.02

# %%
qs.reports.full(rett['eq'], benchmark = rett['btc'], periods_per_year= 4 * 24 *365, compounded=True)
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2020-01-03   2020-01-03
# End Period                 2023-06-30   2023-06-30
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       49.0%
#
# Cumulative Return          333.6%       730.95%
# CAGR﹪                     33.7%        52.07%
#
# Sharpe                     0.93         2.05
# Prob. Sharpe Ratio         96.01%       99.99%
# Smart Sharpe               0.93         2.04
# Sortino                    1.33         2.93
# Smart Sortino              1.33         2.92
# Sortino/√2                 0.94         2.07
# Smart Sortino/√2           0.94         2.06
# Omega                      1.06         1.06
#
# Max Drawdown               -77.27%      -18.49%
# Longest DD Days            597          168
# Volatility (ann.)          74.85%       32.04%
# R^2                        0.28         0.28
# Information Ratio          -0.0         -0.0
# Calmar                     0.44         2.82
# Skew                       1.23         -0.34
# Kurtosis                   150.84       92.44
#
# Expected Daily %           0.0%         0.0%
# Expected Monthly %         3.55%        5.17%
# Expected Yearly %          44.3%        69.78%
# Kelly Criterion            1.05%        2.65%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -0.66%       -0.28%
# Expected Shortfall (cVaR)  -0.66%       -0.28%
#
# Max Consecutive Wins       14           12
# Max Consecutive Losses     13           10
# Gain/Pain Ratio            0.17         0.58
# Gain/Pain (1M)             1.05         5.71
#
# Payoff Ratio               1.01         1.02
# Profit Factor              1.02         1.06
# Common Sense Ratio         1.03         1.13
# CPC Index                  0.52         0.55
# Tail Ratio                 1.01         1.06
# Outlier Win Ratio          3.48         18.51
# Outlier Loss Ratio         3.44         6.02
#
# MTD                        11.79%       10.01%
# 3M                         7.3%         3.6%
# 6M                         82.85%       49.69%
# YTD                        83.87%       49.87%
# 1Y                         51.21%       50.54%
# 3Y (ann.)                  26.89%       43.97%
# 5Y (ann.)                  33.7%        52.07%
# 10Y (ann.)                 33.7%        52.07%
# All-time (ann.)            33.7%        52.07%
#
# Best Day                   23.69%       4.63%
# Worst Day                  -12.58%      -5.64%
# Best Month                 46.81%       25.11%
# Worst Month                -37.34%      -6.89%
# Best Year                  312.84%      194.81%
# Worst Year                 -64.21%      8.41%
#
# Avg. Drawdown              -2.54%       -1.94%
# Avg. Drawdown Days         5            5
# Recovery Factor            3.16         12.42
# Ulcer Index                0.44         0.09
# Serenity Index             0.03         0.3
#
# Avg. Up Month              23.08%       12.75%
# Avg. Down Month            -12.62%      -2.58%
# Win Days %                 50.33%       50.78%
# Win Month %                54.76%       59.52%
# Win Quarter %              57.14%       78.57%
# Win Year %                 75.0%        100.0%
#
# Beta                       -            0.23
# Alpha                      -            0.5
# Correlation                -            52.84%
# Treynor Ratio              -            3232.32%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2022-09-13  2022-10-24  2023-01-13   123    -18.489738        -17.888808
# 2  2021-03-13  2021-07-10  2021-07-26   135    -17.027300        -16.891572
# 3  2022-03-28  2022-07-07  2022-09-12   168    -16.111033        -15.582249
# 4  2021-01-03  2021-01-06  2021-02-09    37    -15.164823        -14.636149
# 5  2023-04-26  2023-05-28  2023-06-30    65    -14.392467        -14.237723
# <h4>Strategy Visualization</h4>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 qs.reports.full(rett['eq'], benchmark = rett['btc'], periods_per_year= 4 * 24 *365, compounded=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/quantstats/reports.py:628, in full(returns, benchmark, rf, grayscale, figsize, display, compounded, periods_per_year, match_dates, **kwargs)
#     625     print("\n\n")
#     626     print("[Strategy Visualization]\nvia Matplotlib")
# --> 628 plots(
#     629     returns=returns,
#     630     benchmark=benchmark,
#     631     grayscale=grayscale,
#     632     figsize=figsize,
#     633     mode="full",
#     634     periods_per_year=periods_per_year,
#     635     prepare_returns=False,
#     636     benchmark_title=benchmark_title,
#     637     strategy_title=strategy_title,
#     638     active=active,
#     639 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/quantstats/reports.py:1387, in plots(returns, benchmark, grayscale, figsize, mode, compounded, periods_per_year, prepare_returns, match_dates, **kwargs)
#    1368 _plots.rolling_volatility(
#    1369     returns,
#    1370     benchmark,
#    (...)
#    1375     period=win_half_year,
#    1376 )
#    1378 _plots.rolling_sharpe(
#    1379     returns,
#    1380     grayscale=grayscale,
#    (...)
#    1384     period=win_half_year,
#    1385 )
# -> 1387 _plots.rolling_sortino(
#    1388     returns,
#    1389     grayscale=grayscale,
#    1390     figsize=small_fig_size,
#    1391     show=True,
#    1392     ylabel=False,
#    1393     period=win_half_year,
#    1394 )
#    1396 if isinstance(returns, _pd.Series):
#    1397     _plots.drawdowns_periods(
#    1398         returns,
#    1399         grayscale=grayscale,
#    (...)
#    1403         prepare_returns=False,
#    1404     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/quantstats/_plotting/wrappers.py:907, in rolling_sortino(returns, benchmark, rf, period, period_label, periods_per_year, lw, fontname, grayscale, figsize, ylabel, subtitle, savefig, show)
#     890 def rolling_sortino(
#     891     returns,
#     892     benchmark=None,
#    (...)
#     904     show=True,
#     905 ):
# --> 907     returns = _stats.rolling_sortino(returns, rf, period, True, periods_per_year)
#     909     if benchmark is not None:
#     910         benchmark = _utils._prepare_benchmark(benchmark, returns.index, rf)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/quantstats/stats.py:371, in rolling_sortino(returns, rf, rolling_period, annualize, periods_per_year, **kwargs)
#     367 if kwargs.get("prepare_returns", True):
#     368     returns = _utils._prepare_returns(returns, rf, rolling_period)
#     370 downside = (
# --> 371     returns.rolling(rolling_period).apply(
#     372         lambda x: (x.values[x.values < 0] ** 2).sum()
#     373     )
#     374     / rolling_period
#     375 )
#     377 res = returns.rolling(rolling_period).mean() / _np.sqrt(downside)
#     378 if annualize:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/window/rolling.py:1913, in Rolling.apply(self, func, raw, engine, engine_kwargs, args, kwargs)
#    1892 @doc(
#    1893     template_header,
#    1894     create_section_header("Parameters"),
#    (...)
#    1911     kwargs: dict[str, Any] | None = None,
#    1912 ):
# -> 1913     return super().apply(
#    1914         func,
#    1915         raw=raw,
#    1916         engine=engine,
#    1917         engine_kwargs=engine_kwargs,
#    1918         args=args,
#    1919         kwargs=kwargs,
#    1920     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/window/rolling.py:1390, in RollingAndExpandingMixin.apply(self, func, raw, engine, engine_kwargs, args, kwargs)
#    1387 else:
#    1388     raise ValueError("engine must be either 'numba' or 'cython'")
# -> 1390 return self._apply(
#    1391     apply_func,
#    1392     name="apply",
#    1393     numba_args=numba_args,
#    1394 )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/window/rolling.py:615, in BaseWindow._apply(self, func, name, numeric_only, numba_args, **kwargs)
#     612     return result
#     614 if self.method == "single":
# --> 615     return self._apply_blockwise(homogeneous_func, name, numeric_only)
#     616 else:
#     617     return self._apply_tablewise(homogeneous_func, name, numeric_only)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/window/rolling.py:490, in BaseWindow._apply_blockwise(self, homogeneous_func, name, numeric_only)
#     486 except (TypeError, NotImplementedError) as err:
#     487     raise DataError(
#     488         f"Cannot aggregate non-numeric type: {arr.dtype}"
#     489     ) from err
# --> 490 res = homogeneous_func(arr)
#     491 res_values.append(res)
#     492 taker.append(i)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/window/rolling.py:610, in BaseWindow._apply.<locals>.homogeneous_func(values)
#     607     return func(x, start, end, min_periods, *numba_args)
#     609 with np.errstate(all="ignore"):
# --> 610     result = calc(values)
#     612 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/window/rolling.py:607, in BaseWindow._apply.<locals>.homogeneous_func.<locals>.calc(x)
#     598 start, end = window_indexer.get_window_bounds(
#     599     num_values=len(x),
#     600     min_periods=min_periods,
#    (...)
#     603     step=self.step,
#     604 )
#     605 self._check_window_bounds(start, end, len(x))
# --> 607 return func(x, start, end, min_periods, *numba_args)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/window/rolling.py:1417, in RollingAndExpandingMixin._generate_cython_apply_func.<locals>.apply_func(values, begin, end, min_periods, raw)
#    1414 if not raw:
#    1415     # GH 45912
#    1416     values = Series(values, index=self._on, copy=False)
# -> 1417 return window_func(values, begin, end, min_periods)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/_libs/window/aggregations.pyx:1423, in pandas._libs.window.aggregations.roll_apply()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/quantstats/stats.py:372, in rolling_sortino.<locals>.<lambda>(x)
#     367 if kwargs.get("prepare_returns", True):
#     368     returns = _utils._prepare_returns(returns, rf, rolling_period)
#     370 downside = (
#     371     returns.rolling(rolling_period).apply(
# --> 372         lambda x: (x.values[x.values < 0] ** 2).sum()
#     373     )
#     374     / rolling_period
#     375 )
#     377 res = returns.rolling(rolling_period).mean() / _np.sqrt(downside)
#     378 if annualize:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/_methods.py:46, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      42 def _amin(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
#      44     return umr_minimum(a, axis, None, out, keepdims, initial, where)
# ---> 46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
#      48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      51           initial=_NoValue, where=True):
#
# KeyboardInterrupt:
